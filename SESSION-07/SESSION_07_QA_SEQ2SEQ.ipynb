# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
data_path ='/content/drive/MyDrive/ENDB2/SESSION-07/QA_DATA/Question_Answer_Dataset_v1.2/'

# %%
s08_data_path = '/content/drive/MyDrive/ENDB2/SESSION-07/QA_DATA/Question_Answer_Dataset_v1.2/S08/question_answer_pairs.txt'

# %%
import pandas as pd 

df= pd.read_csv(s08_data_path, sep="\t", engine='python')
df.head()
# Out:
#       ArticleTitle  ...   ArticleFile
# 0  Abraham_Lincoln  ...  data/set3/a4
# 1  Abraham_Lincoln  ...  data/set3/a4
# 2  Abraham_Lincoln  ...  data/set3/a4
# 3  Abraham_Lincoln  ...  data/set3/a4
# 4  Abraham_Lincoln  ...  data/set3/a4
#
# [5 rows x 6 columns]

# %%
len(df)
# Out:
# 1715

# %%
df_qa=df[['Question','Answer']]
df_qa.tail()
# Out:
#                                                Question                                             Answer
# 1710  Was Wilson president of the American Political...                                                Yes
# 1711  Did he not cast his ballot for John M. Palmer ...                                                Yes
# 1712  Did Wilson not spend 1914 through the beginnin...                                                Yes
# 1713  Was Wilson , a staunch opponent of antisemitis...                                                Yes
# 1714                             What happened in 1917?  raised billions through Liberty loans, imposed...

# %%
df_qa.Answer.value_counts()
# Out:
# Yes                                                                            219
# yes                                                                            211
# no                                                                              58
# No                                                                              57
# Yes.                                                                            52
#                                                                               ...
# Its independence                                                                 1
# Sea otters (Enhydra lutris) live along the Pacific coast of North America.       1
# tiny rows of plates called lamellae like a whale's baleen                        1
# German                                                                           1
# the Spanish                                                                      1
# Name: Answer, Length: 763, dtype: int64

# %%
# Import Library
import random
import torch, torchtext
from torchtext import data 

# Manual Seed
SEED = 43
torch.manual_seed(SEED)

# %%
Question = torchtext.legacy.data.Field(sequential = True, tokenize = 'spacy', batch_first =True, include_lengths=True)
Answer = torchtext.legacy.data.Field(sequential = True, tokenize = 'spacy', batch_first =True, include_lengths=True)
